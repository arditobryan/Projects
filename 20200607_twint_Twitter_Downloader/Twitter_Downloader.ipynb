# %%
#be careful, the use of twint is against the User Service Agreement of Twitter, this is only an experiment

# %%
# !pip3 install twint
# Out:
# ...
#      |████████████████████████████████| 1.2MB 8.4MB/s
# ...
#      |████████████████████████████████| 245kB 23.1MB/s
# ...
#      |████████████████████████████████| 102kB 9.0MB/s
# ...
#      |████████████████████████████████| 153kB 21.3MB/s
# ...
#      |████████████████████████████████| 256kB 22.5MB/s
# ...
#      |████████████████████████████████| 235kB 27.4MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.20-cp36-none-any.whl size=33921 sha256=8c6303d21ea98ecc038716485ff898cdb438093556ca55365cf51422ed15d9c8
#   Stored in directory: /root/.cache/pip/wheels/66/25/c7/855c1d896087ef84df6e6713b8adb073aff99af119450e1e4f
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13484 sha256=7d221f00fabf1fc2de3bbbed44ee5b522a6a2511948019c04da5503e3db5d626
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# ...

# %%
import twint

# Configure
c = twint.Config()
c.Search = "italian citizenship"
c.Store_csv = True
c.Limit = 10000 #non funziona
c.Output = "ita.csv"

# Run
twint.run.Search(c)
# Out:
# 1269519609205420032 2020-06-07 06:40:36 UTC <samikshainfotec> Soniaji though wanted to be PM, she couldn't legally. It was not a sacrifice. She had still retained her Italian citizenship at that time. Honestly, as far as Rahul's conference is concerned, I don't really watch because he just want to showcase that the government is incompetent
# 1269497164121739264 2020-06-07 05:11:24 UTC <gesualdi> @MoRocca @MoRocca I was going to ask if you knew you can qualify for Italian citizenship by birth (through your ggf John Lanza) but then I realized you work for CBS Sunday Morning which has covered the Italian citizenship subject already! Carry on!
# 1269379231630258177 2020-06-06 21:22:47 UTC <dibsonbard> #olivegarden is really commiting to the "when you're here, you're family" slogan. During my last visit the waiter insisted that I was his nephew, and implied I don't call often enough, and the manager claimed I was her father. #Family #UncleWaiter #Olive #ItalianCitizenship
# ...
