# %%
# !pip install numpy-financial

# %%
import numpy_financial 

N = 5
I_R = .0192
PMT = 0
PV = 100
FV = -110

# %%
numpy_financial.fv(rate=I_R, nper=N, pmt=PMT, pv=PV)

# %%
numpy_financial.rate(nper=N, pmt=PMT, pv=PV, fv=FV)

# %%
numpy_financial.nper(rate=I_R, pmt=PMT, pv=PV, fv=FV)

# %%
numpy_financial.pv(rate=I_R, nper=N, pmt=PMT, fv=FV)
