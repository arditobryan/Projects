# %%
import pandas as pd
X = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
X.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
y = X.pop('species')
y = pd.DataFrame(y)

# %%
X.pop('sepal_length')
X.pop('sepal_width')
# Out:
# 0      3.0
# 1      3.2
# 2      3.1
# 3      3.6
# 4      3.9
#       ...
# 144    3.0
# 145    2.5
# 146    3.0
# 147    3.4
# 148    3.0
# Name: sepal_width, Length: 149, dtype: float64

# %%
X.head()
# Out:
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.3          0.2
# 2           1.5          0.2
# 3           1.4          0.2
# 4           1.7          0.4

# %%
y.head()
# Out:
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
from sklearn.model_selection import train_test_split
X2_train, X2_test, y2_train, y2_test = train_test_split(X, y, test_size=0.2, random_state=11)
print(X2_train.shape, X2_test.shape, y2_train.shape, y2_test.shape)

# %% [markdown]
# #Graph by Label

# %%
import matplotlib.pyplot as plt
import seaborn as sns

a = list()
for region, df_region in X.groupby('species'):
  a.append(df_region)

# %%
for k in X.columns[:-1]:
  sns.distplot(a[0][k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %%
for k in X.columns[:-1]:
  sns.distplot(a[1][k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %%
for k in X.columns[:-1]:
  sns.distplot(a[2][k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %% [markdown]
# #Graph by Feature

# %%
import matplotlib.pyplot as plt
import seaborn as sns

a = list()
for region, df_region in X.groupby('species'):
  a.append(df_region)
#otteniamo 3 differenti Dataframe in a
a

b = list()

for c in X.columns[:-1]:
  for l in range(len(a)):
    b.append(pd.DataFrame(a[l][c]))
#b contiente tutte le 12 possibili colonne
b

fig, ax = plt.subplots()
fig.set_size_inches(17.55, 11.4)
for k in range(0,3): #len(X['species'].unique())
  sns.distplot(b[k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(17.55, 11.4)
for k in range(3,6): #len(X['species'].unique())
  sns.distplot(b[k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(17.55, 11.4)
for k in range(6,9): #len(X['species'].unique())
  sns.distplot(b[k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(17.55, 11.4)
for k in range(9,12): #len(X['species'].unique())
  sns.distplot(b[k], hist = True, bins = 10, kde = True, kde_kws = {'linewidth': 1})

# %% [markdown]
# #Prova

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (119, 2) (30, 2) (119, 1) (30, 1)

# %%
#misuriamo accuratezza delle nostre approssimazioni
#Gaussian Naive Bayes
import numpy as np
from sklearn.naive_bayes import GaussianNB

#training the AI
clf = GaussianNB()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# 0.9666666666666667
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
