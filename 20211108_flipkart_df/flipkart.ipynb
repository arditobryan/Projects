# %%
import pandas as pd

pd.read_csv('https://github.com/arditoibryan/Projects/blob/master/20211108_flipkart_df/flipkart_data.csv',sep=';')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19440/2653794622.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv('https://github.com/arditoibryan/Projects/blob/master/20211108_flipkart_df/flipkart_data.csv',sep=';')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_csv('flipkart_data.csv').to_csv('flipkart_data_2.csv')

# %%
    df = df[['product_name', 'description', 'retail_price']]
    df = df.reset_index()
    df.columns = ['_id', 'product_name', 'description', 'retail_price']
    df = df.dropna()
    #df = df[0:30]
