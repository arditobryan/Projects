# %%
import pandas as pd

df = pd.read_csv('wiki_movie_plots_deduped.csv')
df

# %%
df['Origin/Ethnicity'].unique()
# Out:
# array(['American', 'Australian', 'Bangladeshi', 'British', 'Canadian',
#        'Chinese', 'Egyptian', 'Hong Kong', 'Filipino', 'Assamese',
#        'Bengali', 'Bollywood', 'Kannada', 'Malayalam', 'Marathi',
#        'Punjabi', 'Tamil', 'Telugu', 'Japanese', 'Malaysian', 'Maldivian',
#        'Russian', 'South_Korean', 'Turkish'], dtype=object)

# %%
#to exclude: Bangladeshi, Egyptian

# %%
df[df['Origin/Ethnicity']=='Hong Kong']
# Out:
#        Release Year                                      Title  \
# 22963          1951                             The Naked City
# 22964          1951               Hua gu niang The Flower Girl
# 22965          1951  Hong lou xin meng A Dream of Red Mansions
# 22966          1952                Nan wei le ba ba Poor Daddy
# 22967          1952                  Nie yuan Fatal Attraction
# ...             ...                                        ...
# 23749          2016                       Special Female Force
# 23750          2016                                    Trivisa
# 23751          2016                              Weeds on Fire
# 23752          2017                         Always Be With You
# 23753          2017                      The Yuppie Fantasia 3
#
#       Origin/Ethnicity                        Director  \
# 22963        Hong Kong                         Unknown
# 22964        Hong Kong                         Unknown
# ...

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

df_ = df.copy()
df_['Plot'] = df_['Plot'].apply(lambda x : model.encode(x))
df_index = df_.pop('Title')
df_ = df_[['Plot']]
df_ = pd.DataFrame(np.column_stack(list(zip(*df_.values))))
df_.index = df_index
df_.to_csv('wiki_movie_encoded.csv')
